# %% [markdown]
# <a href="https://colab.research.google.com/github/mangare91/Drug_Discover_Portifolio_projects/blob/main/QSARCOVID3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Part 3 Descriptor Calculation and Dataset Preparation
#
# Calculating molecular descriptors that are essentially quantitative description of the compounds in the dataset. Finally, we will be preparing this into a dataset for subsequent model building in Part 4
# Download PaDEL-Descriptor

# %%
# !pip install -c anaconda wget
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'anaconda'

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2020-11-18 20:36:20--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 52.192.72.89
# Connecting to github.com (github.com)|52.192.72.89|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2020-11-18 20:36:21--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip.1’
#
# padel.zip.1         100%[===================>]  24.57M  47.7MB/s    in 0.5s
#
# 2020-11-18 20:36:21 (47.7 MB/s) - ‘padel.zip.1’ saved [25768637/25768637]
#
# ...

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
# replace __MACOSX/._PaDEL-Descriptor? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd
df3 = pd.read_csv("coronavirus_bioactivity_data_pIC50.csv")
df3
# Out:
#     Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0            0       CHEMBL187579  ...           5.0  5.142668
# 1            1       CHEMBL188487  ...           2.0  5.026872
# 2            2       CHEMBL185698  ...           4.0  4.869666
# 3            3       CHEMBL426082  ...           3.0  4.882397
# 4            4       CHEMBL187717  ...           5.0  5.698970
# ..         ...                ...  ...           ...       ...
# 81          81      CHEMBL2146517  ...           5.0  4.675718
# 82          82       CHEMBL187460  ...           3.0  3.644548
# 83          83       CHEMBL363535  ...           3.0  4.412289
# 84          84       CHEMBL227075  ...           3.0  4.841638
# 85          85        CHEMBL45830  ...           2.0  4.675718
#
# [86 rows x 9 columns]

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21	CHEMBL187579
# O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21	CHEMBL188487
# O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21	CHEMBL185698
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21	CHEMBL426082
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]	CHEMBL187717

# %% [markdown]
# Calculate Fingerprint Descriptors
# Calculate PaDEL Descriptors
#
# Automatically removes salts and small organic acids from chemical structure (removing impurities) Creates PubChem Fingerprint (local features of molecule)

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL187579 in molecule.smi (1/86).
# Processing CHEMBL188487 in molecule.smi (2/86).
# Processing CHEMBL185698 in molecule.smi (3/86). Average speed: 1.96 s/mol.
# Processing CHEMBL426082 in molecule.smi (4/86). Average speed: 1.10 s/mol.
# Processing CHEMBL187717 in molecule.smi (5/86). Average speed: 0.92 s/mol.
# Processing CHEMBL365134 in molecule.smi (6/86). Average speed: 0.72 s/mol.
# Processing CHEMBL187598 in molecule.smi (7/86). Average speed: 0.71 s/mol.
# Processing CHEMBL190743 in molecule.smi (8/86). Average speed: 0.60 s/mol.
# Processing CHEMBL365469 in molecule.smi (9/86). Average speed: 0.60 s/mol.
# Processing CHEMBL188983 in molecule.smi (10/86). Average speed: 0.53 s/mol.
# Processing CHEMBL191575 in molecule.smi (11/86). Average speed: 0.52 s/mol.
# Processing CHEMBL370923 in molecule.smi (12/86). Average speed: 0.48 s/mol.
# Processing CHEMBL194398 in molecule.smi (13/86). Average speed: 0.47 s/mol.
# ...

# %%
df3_X = pd.read_csv('descriptors_output.csv')
df3_X = df3_X.drop(columns = ['Name'])
df3_X
# Out:
#     PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0            1           1  ...             0             0
# 1            1           1  ...             0             0
# 2            1           1  ...             0             0
# 3            1           1  ...             0             0
# 4            1           1  ...             0             0
# ..         ...         ...  ...           ...           ...
# 81           1           1  ...             0             0
# 82           1           1  ...             0             0
# 83           1           1  ...             0             0
# 84           1           1  ...             0             0
# 85           1           1  ...             0             0
#
# [86 rows x 881 columns]

# %%
#Convert IC50 to pIC50
df3_Y = df3['pIC50']
df3_Y
# Out:
# 0     5.142668
# 1     5.026872
# 2     4.869666
# 3     4.882397
# 4     5.698970
#         ...
# 81    4.675718
# 82    3.644548
# 83    4.412289
# 84    4.841638
# 85    4.675718
# Name: pIC50, Length: 86, dtype: float64

# %% [markdown]
# Combining x and y values

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis = 1)
dataset3
# Out:
#     PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0            1           1           0  ...             0             0  5.142668
# 1            1           1           0  ...             0             0  5.026872
# 2            1           1           0  ...             0             0  4.869666
# 3            1           1           0  ...             0             0  4.882397
# 4            1           1           0  ...             0             0  5.698970
# ..         ...         ...         ...  ...           ...           ...       ...
# 81           1           1           1  ...             0             0  4.675718
# 82           1           1           1  ...             0             0  3.644548
# 83           1           1           0  ...             0             0  4.412289
# 84           1           1           0  ...             0             0  4.841638
# ...

# %%
dataset3.to_csv('coronavirus_bioactivity_data_pIC50_pubchem_fp.csv', index = False)
